# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\ALL PPP Loan Data\PPP Orig csv Files'
csv_filename = 'public_up_to_150k_9_230101.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4989478404   02/07/2021            235              PPS
# 1  4990207307   04/30/2020            248              PPP
# 2  4994147800   05/29/2020            202              PPP
# 3  4994528302   01/23/2021            202              PPS
# 4  4996487006   04/04/2020            202              PPP
#
#                         BorrowerName           BorrowerAddress  \
# 0          ALISON KATHERINE FRIEDMAN           152 Webster Ave
# 1                THRESHOLD SOLUTIONS    417 E. German Street 1
# 2          MICHAEL O. MARACELLO - SP  1 Teleport Dr, Suite 206
# 3  OPEN DOOR FAMILY LIFE CENTER INC.            999 Greene Ave
# 4         THE SAGE LARGESSE ENDEAVOR              45 NORTH AVE
#
#       BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0        Manhasset            NY  11030-1965     04/30/2022  ...
# 1         Herkimer            NY       13350     05/19/2021  ...
# 2    Staten Island            NY       10314     05/07/2021  ...
# 3         Brooklyn            NY  11221-2910     01/21/2022  ...
# 4  PLEASANT VALLEY            NY  12569-7943     05/12/2021  ...
#
#               BusinessType  OriginatingLenderLocationID  \
# 0      Sole Proprietorship                       121536
# 1      Sole Proprietorship                       434162
# 2      Sole Proprietorship                       455644
# 3  Non-Profit Organization                       531105
# 4      Sole Proprietorship                       101526
#
#                      OriginatingLender  OriginatingLenderCity  \
# 0                       Customers Bank           PHOENIXVILLE
# 1  Citizens Bank, National Association             PROVIDENCE
# 2             Live Oak Banking Company             WILMINGTON
# 3             Liberty SBF Holdings LLC           Philadelphia
# 4                     Hudson Valley CU           POUGHKEEPSIE
#
#    OriginatingLenderState      Gender     Veteran  NonProfit  \
# 0                      PA  Unanswered  Unanswered        NaN
# 1                      RI  Unanswered  Unanswered        NaN
# 2                      NC  Unanswered  Unanswered        NaN
# 3                      PA  Unanswered  Unanswered          Y
# 4                      NY  Unanswered  Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          21033.64      04/05/2022
# 1          20989.76      04/05/2021
# 2          20988.05      04/29/2021
# 3          20947.59      10/20/2021
# 4          20990.90      04/02/2021
#
# [5 rows x 53 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_method = df['ProcessingMethod'] == 'PPP'
condition_NAICS = df['NAICSCode'] == 541330

# Combine the conditions using logical AND
combined_condition = condition_method & condition_NAICS

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#       LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 878   6465238008   06/30/2020            202              PPP
# 1754  7335008103   07/23/2020            202              PPP
# 2482  8843037106   04/15/2020            248              PPP
# 2597  9044997208   04/28/2020            219              PPP
# 2665  9177177409   05/19/2020            219              PPP
#
#                      BorrowerName               BorrowerAddress  \
# 878                 EVA ZUCKERMAN        37 Bank Street apt 1 g
# 1754               THOMAS SZEKELY            99 Wall Street 346
# 2482          CAZ ENTERPRISES,LLC        6320 Fly Road Ste. 207
# 2597  MATT FRONK & ASSOCIATES LLC  66 Quaker Meeting House Road
# 2665           JTF AUTOMATION LLC            15 Melbourne Green
#
#        BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 878        NEW YORK            NY  10014-5255     02/19/2022  ...
# 1754       New York            NY       10005     11/18/2021  ...
# 2482  East Syracuse            NY       13057     06/19/2021  ...
# 2597  Honeoye Falls            NY       14472     01/22/2021  ...
# 2665       Fairport            NY       14450     01/15/2022  ...
#
#                          BusinessType  OriginatingLenderLocationID  \
# 878               Sole Proprietorship                       203241
# 1754        Self-Employed Individuals                        49274
# 2482  Limited  Liability Company(LLC)                        46391
# 2597  Limited  Liability Company(LLC)                        46391
# 2665  Limited  Liability Company(LLC)                       434162
#
#                             OriginatingLender  OriginatingLenderCity  \
# 878                        BCB Community Bank                BAYONNE
# 1754                           Citibank, N.A.            SIOUX FALLS
# 2482  Manufacturers and Traders Trust Company                BUFFALO
# 2597  Manufacturers and Traders Trust Company                BUFFALO
# 2665      Citizens Bank, National Association             PROVIDENCE
#
#       OriginatingLenderState        Gender      Veteran  NonProfit  \
# 878                       NJ  Female Owned   Unanswered        NaN
# 1754                      SD    Male Owned  Non-Veteran        NaN
# 2482                      NY    Unanswered   Unanswered        NaN
# 2597                      NY    Unanswered   Unanswered        NaN
# 2665                      RI    Unanswered   Unanswered        NaN
#
#      ForgivenessAmount ForgivenessDate
# 878           20957.28      04/05/2021
# 1754          21049.02      10/12/2021
# 2482          21014.84      05/06/2021
# 2597          20933.35      12/22/2020
# 2665          21123.11      12/15/2021
#
# [5 rows x 53 columns]

# %%
df_filtered.shape
# Out:
# (1579, 53)

# %%
# Define the CSV filename
filtered_csv_filename = 'PPP_NAICS_Eng_9.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\ALL PPP Loan Data\PPP Orig csv Files\PPP_NAICS_Eng_9.csv'
