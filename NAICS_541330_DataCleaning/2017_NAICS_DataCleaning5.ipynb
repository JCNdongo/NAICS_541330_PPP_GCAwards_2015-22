# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2017 FULL Award Data Archive'
csv_filename = 'FY2017_All_Contracts_Full_20230608_5.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,27,47,70,71,80,113,133,134,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  contract_transaction_unique_key  \
# 0              9700_9700_0008_1A_M6785414D5001_0
# 1               9700_9700_B127_0_SPE2DX15D9304_0
# 2  4740_4740_GSP0617TH0006_PC01_GS06P14GXD0017_0
# 3            4732_-NONE-_GSL005054717_0_-NONE-_0
# 4               9700_9700_03GX_0_SPE30016D4017_0
#
#                          contract_award_unique_key  award_id_piid  \
# 0            CONT_AWD_0008_9700_M6785414D5001_9700           0008
# 1            CONT_AWD_B127_9700_SPE2DX15D9304_9700           B127
# 2  CONT_AWD_GSP0617TH0006_4740_GS06P14GXD0017_4740  GSP0617TH0006
# 3         CONT_AWD_GSL005054717_4732_-NONE-_-NONE-   GSL005054717
# 4            CONT_AWD_03GX_9700_SPE30016D4017_9700           03GX
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0                  1A                 0.0                   9700
# 1                   0                 0.0                   9700
# 2                PC01                 0.0                   4740
# 3                   0                 0.0                    NaN
# 4                   0                 0.0                   9700
#
#    parent_award_agency_name parent_award_id_piid  \
# 0           DEPT OF DEFENSE        M6785414D5001
# 1           DEPT OF DEFENSE        SPE2DX15D9304
# 2  PUBLIC BUILDINGS SERVICE       GS06P14GXD0017
# 3                       NaN                  NaN
# 4           DEPT OF DEFENSE        SPE30016D4017
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                                0                        0.0  ...
# 1                                0                    13500.0  ...
# 2                                0                     2200.0  ...
# 3                              NaN                     7062.0  ...
# 4                                0                       78.4  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_000...          2016-12-20
# 1  https://www.usaspending.gov/award/CONT_AWD_B12...          2019-08-02
# 2  https://www.usaspending.gov/award/CONT_AWD_GSP...          2016-12-20
# 3  https://www.usaspending.gov/award/CONT_AWD_GSL...          2018-03-09
# 4  https://www.usaspending.gov/award/CONT_AWD_03G...          2019-11-26
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                        contract_transaction_unique_key  \
# 53           9700_-NONE-_W9127817D0004_0_-NONE-_-NONE-
# 519                   9700_9700_0001_2_N6833516D0020_0
# 573                   9700_9700_0003_4_N6523612D3882_0
# 702                  9700_9700_J101_39_N0017807D4928_0
# 729  4730_-NONE-_GS10F0100T_PS0013REVTERMCOND_-NONE...
#
#                  contract_award_unique_key  award_id_piid modification_number  \
# 53             CONT_IDV_W9127817D0004_9700  W9127817D0004                   0
# 519  CONT_AWD_0001_9700_N6833516D0020_9700           0001                   2
# 573  CONT_AWD_0003_9700_N6523612D3882_9700           0003                   4
# 702  CONT_AWD_J101_9700_N0017807D4928_9700           J101                  39
# 729               CONT_IDV_GS10F0100T_4730     GS10F0100T   PS0013REVTERMCOND
#
#      transaction_number parent_award_agency_id parent_award_agency_name  \
# 53                  NaN                    NaN                      NaN
# 519                 0.0                   9700          DEPT OF DEFENSE
# 573                 0.0                   9700          DEPT OF DEFENSE
# 702                 0.0                   9700          DEPT OF DEFENSE
# 729                 NaN                    NaN                      NaN
#
#     parent_award_id_piid parent_award_modification_number  \
# 53                   NaN                              NaN
# 519        N6833516D0020                                0
# 573        N6523612D3882                                0
# 702        N0017807D4928                                0
# 729                  NaN                              NaN
#
#      federal_action_obligation  ...  highly_compensated_officer_2_name  \
# 53                         0.0  ...                                NaN
# 519                   592486.0  ...                                NaN
# 573                   145000.0  ...                                NaN
# 702                   100000.0  ...                                NaN
# 729                        0.0  ...                                NaN
#
#      highly_compensated_officer_2_amount  highly_compensated_officer_3_name  \
# 53                                   NaN                                NaN
# 519                                  NaN                                NaN
# 573                                  NaN                                NaN
# 702                                  NaN                                NaN
# 729                                  NaN                                NaN
#
#      highly_compensated_officer_3_amount  highly_compensated_officer_4_name  \
# 53                                   NaN                                NaN
# 519                                  NaN                                NaN
# 573                                  NaN                                NaN
# 702                                  NaN                                NaN
# 729                                  NaN                                NaN
#
#      highly_compensated_officer_4_amount  highly_compensated_officer_5_name  \
# 53                                   NaN                                NaN
# 519                                  NaN                                NaN
# 573                                  NaN                                NaN
# 702                                  NaN                                NaN
# 729                                  NaN                                NaN
#
#      highly_compensated_officer_5_amount  \
# 53                                   NaN
# 519                                  NaN
# 573                                  NaN
# 702                                  NaN
# 729                                  NaN
#
#                                  usaspending_permalink  last_modified_date
# 53   https://www.usaspending.gov/award/CONT_IDV_W91...          2016-12-20
# 519  https://www.usaspending.gov/award/CONT_AWD_000...          2016-12-20
# 573  https://www.usaspending.gov/award/CONT_AWD_000...          2016-12-20
# 702  https://www.usaspending.gov/award/CONT_AWD_J10...          2016-12-20
# 729  https://www.usaspending.gov/award/CONT_IDV_GS1...          2016-12-20
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (7246, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2017_NAICS_Eng_5.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2017 FULL Award Data Archive\2017_NAICS_Eng_5.csv'
