# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2019 FULL Award Data Archive'
csv_filename = 'FY2019_All_Contracts_Full_20230608_4.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,47,61,70,71,80,113,133,134,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              contract_transaction_unique_key  \
# 0       9700_-NONE-_SPE7MC19P3941_0_-NONE-_0
# 1  9700_9700_SPE7M119FAC2V_0_SPE7LX16D0023_0
# 2  9700_9700_SPE4A619FC8PT_0_SPE4AX16D9010_0
# 3  9700_9700_SPE4A619FC8RN_0_SPE4AX16D9008_0
# 4       9700_-NONE-_SPE4A619PD703_0_-NONE-_0
#
#                         contract_award_unique_key  award_id_piid  \
# 0       CONT_AWD_SPE7MC19P3941_9700_-NONE-_-NONE-  SPE7MC19P3941
# 1  CONT_AWD_SPE7M119FAC2V_9700_SPE7LX16D0023_9700  SPE7M119FAC2V
# 2  CONT_AWD_SPE4A619FC8PT_9700_SPE4AX16D9010_9700  SPE4A619FC8PT
# 3  CONT_AWD_SPE4A619FC8RN_9700_SPE4AX16D9008_9700  SPE4A619FC8RN
# 4       CONT_AWD_SPE4A619PD703_9700_-NONE-_-NONE-  SPE4A619PD703
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0                   0                 0.0                    NaN
# 1                   0                 0.0                   9700
# 2                   0                 0.0                   9700
# 3                   0                 0.0                   9700
# 4                   0                 0.0                    NaN
#
#   parent_award_agency_name parent_award_id_piid  \
# 0                      NaN                  NaN
# 1          DEPT OF DEFENSE        SPE7LX16D0023
# 2          DEPT OF DEFENSE        SPE4AX16D9010
# 3          DEPT OF DEFENSE        SPE4AX16D9008
# 4                      NaN                  NaN
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                              NaN                     437.89  ...
# 1                           ARZ999                      55.76  ...
# 2                                0                     158.22  ...
# 3                                0                      16.59  ...
# 4                              NaN                     450.00  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-10-26
# 1  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-04-27
# 2  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-09-26
# 3  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-07-20
# 4  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-10-26
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, NAICS Code, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                    contract_transaction_unique_key  \
# 25  9700_-NONE-_N0017816D8611_P00005_-NONE-_-NONE-
# 31  9700_-NONE-_N0017816D8533_P00005_-NONE-_-NONE-
# 38               9700_9700_0006_19_W56HZV15DKB22_2
# 43  9700_-NONE-_N0017816D8529_P00005_-NONE-_-NONE-
# 45  9700_-NONE-_N0017812D6880_P00017_-NONE-_-NONE-
#
#                 contract_award_unique_key  award_id_piid modification_number  \
# 25            CONT_IDV_N0017816D8611_9700  N0017816D8611              P00005
# 31            CONT_IDV_N0017816D8533_9700  N0017816D8533              P00005
# 38  CONT_AWD_0006_9700_W56HZV15DKB22_9700           0006                  19
# 43            CONT_IDV_N0017816D8529_9700  N0017816D8529              P00005
# 45            CONT_IDV_N0017812D6880_9700  N0017812D6880              P00017
#
#     transaction_number parent_award_agency_id parent_award_agency_name  \
# 25                 NaN                    NaN                      NaN
# 31                 NaN                    NaN                      NaN
# 38                 2.0                   9700          DEPT OF DEFENSE
# 43                 NaN                    NaN                      NaN
# 45                 NaN                    NaN                      NaN
#
#    parent_award_id_piid parent_award_modification_number  \
# 25                  NaN                              NaN
# 31                  NaN                              NaN
# 38        W56HZV15DKB22                                0
# 43                  NaN                              NaN
# 45                  NaN                              NaN
#
#     federal_action_obligation  ...  highly_compensated_officer_2_name  \
# 25                        0.0  ...                                NaN
# 31                        0.0  ...                                NaN
# 38                    15000.0  ...                       DAVID  STAPP
# 43                        0.0  ...                                NaN
# 45                        0.0  ...                                NaN
#
#     highly_compensated_officer_2_amount  highly_compensated_officer_3_name  \
# 25                                  NaN                                NaN
# 31                                  NaN                                NaN
# 38                             234178.0                         HONG  DENG
# 43                                  NaN                                NaN
# 45                                  NaN                                NaN
#
#     highly_compensated_officer_3_amount  highly_compensated_officer_4_name  \
# 25                                  NaN                                NaN
# 31                                  NaN                                NaN
# 38                             228545.0                  RICHARD  POPOVICH
# 43                                  NaN                                NaN
# 45                                  NaN                                NaN
#
#     highly_compensated_officer_4_amount  highly_compensated_officer_5_name  \
# 25                                  NaN                                NaN
# 31                                  NaN                                NaN
# 38                             203545.0                   CHARLES  BOGGESS
# 43                                  NaN                                NaN
# 45                                  NaN                                NaN
#
#     highly_compensated_officer_5_amount  \
# 25                                  NaN
# 31                                  NaN
# 38                             202310.0
# 43                                  NaN
# 45                                  NaN
#
#                                 usaspending_permalink  last_modified_date
# 25  https://www.usaspending.gov/award/CONT_IDV_N00...          2022-10-28
# 31  https://www.usaspending.gov/award/CONT_IDV_N00...          2022-10-28
# 38  https://www.usaspending.gov/award/CONT_AWD_000...          2019-04-16
# 43  https://www.usaspending.gov/award/CONT_IDV_N00...          2022-10-30
# 45  https://www.usaspending.gov/award/CONT_IDV_N00...          2022-12-04
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (8287, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2019_NAICS_Eng_4.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2019 FULL Award Data Archive\2019_NAICS_Eng_4.csv'
