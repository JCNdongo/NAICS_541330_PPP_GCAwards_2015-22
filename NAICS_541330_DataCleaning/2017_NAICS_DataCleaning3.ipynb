# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2017 FULL Award Data Archive'
csv_filename = 'FY2017_All_Contracts_Full_20230608_3.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,27,47,61,70,71,80,113,133,134,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                   contract_transaction_unique_key  \
# 0     7001_7001_HSHQDC17J00166_0_HSHQDC13D00019_0
# 1       1544_1544_DJM17D76D0076_7_DJM15A32V0006_0
# 2                9700_9700_088N_0_SPM8EG14D0002_0
# 3  1549_-NONE-_DJF141200S0004680_10_-NONE-_-NONE-
# 4                9700_9700_CJ11_0_SPE2DX15D3401_0
#
#                           contract_award_unique_key      award_id_piid  \
# 0  CONT_AWD_HSHQDC17J00166_7001_HSHQDC13D00019_7001     HSHQDC17J00166
# 1    CONT_AWD_DJM17D76D0076_1544_DJM15A32V0006_1544      DJM17D76D0076
# 2             CONT_AWD_088N_9700_SPM8EG14D0002_9700               088N
# 3                   CONT_IDV_DJF141200S0004680_1549  DJF141200S0004680
# 4             CONT_AWD_CJ11_9700_SPE2DX15D3401_9700               CJ11
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0                   0                 0.0                   7001
# 1                   7                 0.0                   1544
# 2                   0                 0.0                   9700
# 3                  10                 NaN                    NaN
# 4                   0                 0.0                   9700
#
#            parent_award_agency_name parent_award_id_piid  \
# 0  OFFICE OF PROCUREMENT OPERATIONS       HSHQDC13D00019
# 1             U.S. MARSHALS SERVICE        DJM15A32V0006
# 2                   DEPT OF DEFENSE        SPM8EG14D0002
# 3                               NaN                  NaN
# 4                   DEPT OF DEFENSE        SPE2DX15D3401
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                                0                    5680.00  ...
# 1                                0                  622923.98  ...
# 2                                0                   13835.48  ...
# 3                              NaN                   15000.00  ...
# 4                                0                   17694.55  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                        GUY A STONE                             458446.0
# 1                                NaN                                  NaN
# 2                     MARK  ROBINSON                             228654.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                     VAUGHN  HOWARD                             272918.0
# 1                                NaN                                  NaN
# 2                     STEVEN  COTONE                             210539.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                     ERIC  MARTINIS                             257884.0
# 1                                NaN                                  NaN
# 2                    PATRICK  VOLLER                             182308.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                        DYLAN  SLAY                             222380.0
# 1                                NaN                                  NaN
# 2                       BRYAN  DAVIS                             145000.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_HSH...          2023-02-08
# 1  https://www.usaspending.gov/award/CONT_AWD_DJM...          2017-05-24
# 2  https://www.usaspending.gov/award/CONT_AWD_088...          2019-12-21
# 3  https://www.usaspending.gov/award/CONT_IDV_DJF...          2018-07-05
# 4  https://www.usaspending.gov/award/CONT_AWD_CJ1...          2019-06-06
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                        contract_transaction_unique_key  \
# 27   1330_1330_DOCDG133W12CQ0010T0019_P0004_DOCDG13...
# 58               8900_8900_DEBP0004748_3_DEEE0006650_0
# 219        7008_-NONE-_HSCG5014PPKUGH1_P00003_-NONE-_0
# 338                  6920_6920_0003_1_DTFAWA16D00014_0
# 475     9700_-NONE-_W31P4Q16A0010_P00005_-NONE-_-NONE-
#
#                              contract_award_unique_key  \
# 27   CONT_AWD_DOCDG133W12CQ0010T0019_1330_DOCDG133W...
# 58          CONT_AWD_DEBP0004748_8900_DEEE0006650_8900
# 219        CONT_AWD_HSCG5014PPKUGH1_7008_-NONE-_-NONE-
# 338             CONT_AWD_0003_6920_DTFAWA16D00014_6920
# 475                        CONT_IDV_W31P4Q16A0010_9700
#
#               award_id_piid modification_number  transaction_number  \
# 27   DOCDG133W12CQ0010T0019               P0004                 0.0
# 58              DEBP0004748                   3                 0.0
# 219         HSCG5014PPKUGH1              P00003                 0.0
# 338                    0003                   1                 0.0
# 475           W31P4Q16A0010              P00005                 NaN
#
#     parent_award_agency_id                         parent_award_agency_name  \
# 27                    1330  NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION
# 58                    8900                            ENERGY, DEPARTMENT OF
# 219                    NaN                                              NaN
# 338                   6920                  FEDERAL AVIATION ADMINISTRATION
# 475                   4730                      FEDERAL ACQUISITION SERVICE
#
#     parent_award_id_piid parent_award_modification_number  \
# 27     DOCDG133W12CQ0010                                0
# 58           DEEE0006650                                7
# 219                  NaN                              NaN
# 338       DTFAWA16D00014                                0
# 475           GS23F0320N                 PA0017ADDRESSCHG
#
#      federal_action_obligation  ...  highly_compensated_officer_2_name  \
# 27                    62491.20  ...                                NaN
# 58                    -6580.83  ...                    JONATHAN  ELDER
# 219                  -60329.30  ...                                NaN
# 338                   60000.00  ...                                NaN
# 475                       0.00  ...                                NaN
#
#      highly_compensated_officer_2_amount  highly_compensated_officer_3_name  \
# 27                                   NaN                                NaN
# 58                              375098.0                   GEORGE C SPENCER
# 219                                  NaN                                NaN
# 338                                  NaN                                NaN
# 475                                  NaN                                NaN
#
#      highly_compensated_officer_3_amount  highly_compensated_officer_4_name  \
# 27                                   NaN                                NaN
# 58                              359479.0                     WILLIAM M HUNT
# 219                                  NaN                                NaN
# 338                                  NaN                                NaN
# 475                                  NaN                                NaN
#
#      highly_compensated_officer_4_amount  highly_compensated_officer_5_name  \
# 27                                   NaN                                NaN
# 58                              216442.0                    JESSE  GOELLNER
# 219                                  NaN                                NaN
# 338                                  NaN                                NaN
# 475                                  NaN                                NaN
#
#      highly_compensated_officer_5_amount  \
# 27                                   NaN
# 58                              205934.0
# 219                                  NaN
# 338                                  NaN
# 475                                  NaN
#
#                                  usaspending_permalink  last_modified_date
# 27   https://www.usaspending.gov/award/CONT_AWD_DOC...          2017-05-24
# 58   https://www.usaspending.gov/award/CONT_AWD_DEB...          2020-07-14
# 219  https://www.usaspending.gov/award/CONT_AWD_HSC...          2017-05-24
# 338  https://www.usaspending.gov/award/CONT_AWD_000...          2017-05-24
# 475  https://www.usaspending.gov/award/CONT_IDV_W31...          2018-02-01
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (6921, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2017_NAICS_Eng_3.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2017 FULL Award Data Archive\2017_NAICS_Eng_3.csv'
