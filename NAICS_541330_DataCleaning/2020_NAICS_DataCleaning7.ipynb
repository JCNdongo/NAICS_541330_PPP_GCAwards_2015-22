# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2020 FULL Award Data Archive'
csv_filename = 'FY2020_All_Contracts_Full_20230608_7.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,47,70,71,80,113,133,134,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              contract_transaction_unique_key  \
# 0  9700_9700_SPE30020F0H2Z_0_SPE30018DW589_0
# 1  9700_9700_SPE3SU20F1E2J_0_SPE30018DS334_0
# 2  9700_9700_SPE3SU20F1EDC_0_SPE30018DS325_0
# 3  9700_9700_SPE4A620FA7KW_0_SPE4AX16D9008_0
# 4  9700_9700_SPE4A620FA8CJ_0_SPE4AX16D9008_0
#
#                         contract_award_unique_key  award_id_piid  \
# 0  CONT_AWD_SPE30020F0H2Z_9700_SPE30018DW589_9700  SPE30020F0H2Z
# 1  CONT_AWD_SPE3SU20F1E2J_9700_SPE30018DS334_9700  SPE3SU20F1E2J
# 2  CONT_AWD_SPE3SU20F1EDC_9700_SPE30018DS325_9700  SPE3SU20F1EDC
# 3  CONT_AWD_SPE4A620FA7KW_9700_SPE4AX16D9008_9700  SPE4A620FA7KW
# 4  CONT_AWD_SPE4A620FA8CJ_9700_SPE4AX16D9008_9700  SPE4A620FA8CJ
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0                   0                 0.0                   9700
# 1                   0                 0.0                   9700
# 2                   0                 0.0                   9700
# 3                   0                 0.0                   9700
# 4                   0                 0.0                   9700
#
#   parent_award_agency_name parent_award_id_piid  \
# 0          DEPT OF DEFENSE        SPE30018DW589
# 1          DEPT OF DEFENSE        SPE30018DS334
# 2          DEPT OF DEFENSE        SPE30018DS325
# 3          DEPT OF DEFENSE        SPE4AX16D9008
# 4          DEPT OF DEFENSE        SPE4AX16D9008
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                                0                      47.00  ...
# 1                                0                     206.12  ...
# 2                                0                     212.34  ...
# 3                                0                     391.72  ...
# 4                                0                     354.33  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-10-23
# 1  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-12-18
# 2  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-12-18
# 3  https://www.usaspending.gov/award/CONT_AWD_SPE...          2020-02-08
# 4  https://www.usaspending.gov/award/CONT_AWD_SPE...          2019-11-09
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, NAICS Code, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                      contract_transaction_unique_key  \
# 71         1900_1900_19AQMM20F0010_0_SAQMMA15D0030_0
# 87   9700_4732_FA910119F2004_P00001_GS00Q14OADS133_0
# 97    9700_9700_N0042119F2799_P00006_N0042119D0024_0
# 156   9700_9700_N6449819F3001_P00004_N0017815D8228_0
# 158   4732_-NONE-_47QSWA20D000K_PO0001_-NONE-_-NONE-
#
#                            contract_award_unique_key  award_id_piid  \
# 71    CONT_AWD_19AQMM20F0010_1900_SAQMMA15D0030_1900  19AQMM20F0010
# 87   CONT_AWD_FA910119F2004_9700_GS00Q14OADS133_4732  FA910119F2004
# 97    CONT_AWD_N0042119F2799_9700_N0042119D0024_9700  N0042119F2799
# 156   CONT_AWD_N6449819F3001_9700_N0017815D8228_9700  N6449819F3001
# 158                      CONT_IDV_47QSWA20D000K_4732  47QSWA20D000K
#
#     modification_number  transaction_number parent_award_agency_id  \
# 71                    0                 0.0                   1900
# 87               P00001                 0.0                   4732
# 97               P00006                 0.0                   9700
# 156              P00004                 0.0                   9700
# 158              PO0001                 NaN                    NaN
#
#         parent_award_agency_name parent_award_id_piid  \
# 71          STATE, DEPARTMENT OF        SAQMMA15D0030
# 87   FEDERAL ACQUISITION SERVICE       GS00Q14OADS133
# 97               DEPT OF DEFENSE        N0042119D0024
# 156              DEPT OF DEFENSE        N0017815D8228
# 158                          NaN                  NaN
#
#     parent_award_modification_number  federal_action_obligation  ...  \
# 71                                 0                   44895.14  ...
# 87                  PO0002NOVATAGREE                  125000.00  ...
# 97                                 0                       0.00  ...
# 156                           P00004                       0.00  ...
# 158                              NaN                       0.00  ...
#
#      highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 71                                 NaN                                  NaN
# 87                    MICHAEL A WRIGHT                             231820.0
# 97                                 NaN                                  NaN
# 156                                NaN                                  NaN
# 158                                NaN                                  NaN
#
#      highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 71                                 NaN                                  NaN
# 87                      BOBBY P VEAZEY                             221713.0
# 97                                 NaN                                  NaN
# 156                                NaN                                  NaN
# 158                                NaN                                  NaN
#
#      highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 71                                 NaN                                  NaN
# 87                       AMBER N SCOTT                             208079.0
# 97                                 NaN                                  NaN
# 156                                NaN                                  NaN
# 158                                NaN                                  NaN
#
#      highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 71                                 NaN                                  NaN
# 87                   CURTIS J CHILDERS                             203981.0
# 97                                 NaN                                  NaN
# 156                                NaN                                  NaN
# 158                                NaN                                  NaN
#
#                                  usaspending_permalink  last_modified_date
# 71   https://www.usaspending.gov/award/CONT_AWD_19A...          2019-10-22
# 87   https://www.usaspending.gov/award/CONT_AWD_FA9...          2020-03-14
# 97   https://www.usaspending.gov/award/CONT_AWD_N00...          2019-10-22
# 156  https://www.usaspending.gov/award/CONT_AWD_N64...          2021-03-04
# 158  https://www.usaspending.gov/award/CONT_IDV_47Q...          2022-11-23
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (1091, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2020_NAICS_Eng_7.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2020 FULL Award Data Archive\2020_NAICS_Eng_7.csv'
