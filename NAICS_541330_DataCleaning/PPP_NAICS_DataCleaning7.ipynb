# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\ALL PPP Loan Data\PPP Orig csv Files'
csv_filename = 'public_up_to_150k_7_230101.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (50) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4495888202   08/06/2020            515              PPP
# 1  4520597009   04/03/2020            515              PPP
# 2  4740058608   03/18/2021            515              PPS
# 3  4760788307   01/23/2021            515              PPS
# 4  4763967105   04/13/2020            515              PPP
#
#                             BorrowerName     BorrowerAddress  \
# 0  THE COVE BAR AND GRILL PROPERTIES LLC         6365 US 223
# 1      SEUNG - NI FIT CLUB BAY CITY, LLC      4420 WILDER RD
# 2                            DARL M RENN     8228 Outer Dr S
# 3               VISENTIN ENTERPRISES LLC  657 Sunningdale Dr
# 4                   BEDNARSKI FARMS INC.   60 W CASS CITY RD
#
#           BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0              Addison            MI  49220-9732     05/08/2021  ...
# 1             BAY CITY            MI  48706-2244     02/20/2021  ...
# 2        Traverse City            MI  49685-8689     07/17/2021  ...
# 3  Grosse Pointe Woods            MI  48236-1627            NaN  ...
# 4           UNIONVILLE            MI  48767-9750     03/05/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        84349
# 1              Sole Proprietorship                       378002
# 2              Sole Proprietorship                       203327
# 3  Limited  Liability Company(LLC)                       434162
# 4                      Corporation                       222717
#
#                      OriginatingLender  OriginatingLenderCity  \
# 0                         Premier Bank             YOUNGSTOWN
# 1                       1st State Bank                SAGINAW
# 2                Nicolet National Bank              GREEN BAY
# 3  Citizens Bank, National Association             PROVIDENCE
# 4                       Northstar Bank                BAD AXE
#
#    OriginatingLenderState      Gender      Veteran  NonProfit  \
# 0                      OH  Male Owned  Non-Veteran        NaN
# 1                      MI  Unanswered   Unanswered        NaN
# 2                      WI  Male Owned  Non-Veteran        NaN
# 3                      RI  Male Owned      Veteran        NaN
# 4                      MI  Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0           9758.47      03/31/2021
# 1           9775.71      01/20/2021
# 2           9721.83      06/15/2021
# 3               NaN             NaN
# 4           9780.56      02/09/2021
#
# [5 rows x 53 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_method = df['ProcessingMethod'] == 'PPP'
condition_NAICS = df['NAICSCode'] == 541330

# Combine the conditions using logical AND
combined_condition = condition_method & condition_NAICS

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#       LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 631   3692427202   04/27/2020            515              PPP
# 2524  9017637101   04/15/2020            515              PPP
# 2947  3218767703   05/01/2020            515              PPP
# 3022  3726317203   04/27/2020            515              PPP
# 3755  8089808606   03/24/2021            515              PPP
#
#                                         BorrowerName        BorrowerAddress  \
# 631                                   COBEEN'S, INC.    160 Pepperidge Lane
# 2524                       LAWRENCE ENGINEERING P.C.  4344 SILVER LAKE ROAD
# 2947               ADVANCED MANUFACTURING GROUP, LLC        10525 ELGIN AVE
# 3022  WOLVERINE MICROWAVE ENGINEERING SERVICES, INC.         6596 N 32ND ST
# 3755              WLD III ENGINEERING CONSULTANT LLC   2860 High Meadows Ct
#
#        BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 631    Battle Creek            MI  49015-3110     03/04/2021  ...
# 2524         LINDEN            MI       48451     11/18/2020  ...
# 2947  HUNTINGTN WDS            MI       48070     05/21/2021  ...
# 3022       RICHLAND            MI  49083-9420     12/22/2020  ...
# 3755     Ortonville            MI  48462-9177     10/19/2021  ...
#
#                          BusinessType  OriginatingLenderLocationID  \
# 631          Subchapter S Corporation                        98710
# 2524                      Cooperative                        98847
# 2947  Limited  Liability Company(LLC)                        48270
# 3022         Subchapter S Corporation                        98773
# 3755         Subchapter S Corporation                       317954
#
#                               OriginatingLender  OriginatingLenderCity  \
# 631                                    Honor CU        BERRIEN SPRINGS
# 2524                          Dort Financial CU            GRAND BLANC
# 2947  JPMorgan Chase Bank, National Association               COLUMBUS
# 3022                          Omni Community CU           BATTLE CREEK
# 3755        Newtek Small Business Finance, Inc.           LAKE SUCCESS
#
#       OriginatingLenderState      Gender      Veteran  NonProfit  \
# 631                       MI  Male Owned  Non-Veteran        NaN
# 2524                      MI  Unanswered   Unanswered        NaN
# 2947                      OH  Male Owned  Non-Veteran        NaN
# 3022                      MI  Unanswered   Unanswered        NaN
# 3755                      NY  Male Owned  Non-Veteran        NaN
#
#      ForgivenessAmount ForgivenessDate
# 631            9658.92      02/17/2021
# 2524           9359.22      10/08/2020
# 2947           9331.82      04/26/2021
# 3022           9276.62      12/10/2020
# 3755           9125.02      09/20/2021
#
# [5 rows x 53 columns]

# %%
df_filtered.shape
# Out:
# (1673, 53)

# %%
# Define the CSV filename
filtered_csv_filename = 'PPP_NAICS_Eng_7.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\ALL PPP Loan Data\PPP Orig csv Files\PPP_NAICS_Eng_7.csv'
