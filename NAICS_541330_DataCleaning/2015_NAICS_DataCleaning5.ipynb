# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive'
csv_filename = 'FY2015_All_Contracts_Full_20230608_5.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,26,27,40,41,42,43,52,61,68,70,71,80,85,86,87,88,89,99,100,113,133,135,162,163,168,282,284,286,288,290) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     contract_transaction_unique_key              contract_award_unique_key  \
# 0  9700_9700_0053_0_SP060013D0103_0  CONT_AWD_0053_9700_SP060013D0103_9700
# 1  9700_9700_1043_0_SP060013D0026_0  CONT_AWD_1043_9700_SP060013D0026_9700
# 2  9700_9700_1050_0_SP060013D0026_0  CONT_AWD_1050_9700_SP060013D0026_9700
# 3  9700_9700_0056_0_SP060012D0098_0  CONT_AWD_0056_9700_SP060012D0098_9700
# 4  9700_9700_0056_0_SP060014D0060_0  CONT_AWD_0056_9700_SP060014D0060_9700
#
#   award_id_piid modification_number  transaction_number  \
# 0          0053                   0                 0.0
# 1          1043                   0                 0.0
# 2          1050                   0                 0.0
# 3          0056                   0                 0.0
# 4          0056                   0                 0.0
#
#   parent_award_agency_id parent_award_agency_name parent_award_id_piid  \
# 0                 9700.0                      NaN        SP060013D0103
# 1                 9700.0                      NaN        SP060013D0026
# 2                 9700.0                      NaN        SP060013D0026
# 3                 9700.0                      NaN        SP060012D0098
# 4                 9700.0                      NaN        SP060014D0060
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                                0                   11049.16  ...
# 1                                0                     229.44  ...
# 2                                0                     101.53  ...
# 3                                0                     683.65  ...
# 4                                0                    5761.16  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_005...          2017-07-17
# 1  https://www.usaspending.gov/award/CONT_AWD_104...          2017-04-13
# 2  https://www.usaspending.gov/award/CONT_AWD_105...          2017-04-13
# 3  https://www.usaspending.gov/award/CONT_AWD_005...          2016-03-25
# 4  https://www.usaspending.gov/award/CONT_AWD_005...          2017-04-13
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                      contract_transaction_unique_key  \
# 44342         8000_-NONE-_NND12AB92Z_1_-NONE-_-NONE-
# 45630               9700_9700_0066_2_FA252113D0005_0
# 47183         8000_-NONE-_NND12AB90Z_1_-NONE-_-NONE-
# 48419  7527_7527_HHSI24103045T_0_HHSI241201000011I_0
# 48807              9700_9700_L601_53_N0017804D4001_0
#
#                                contract_award_unique_key  award_id_piid  \
# 44342                           CONT_IDV_NND12AB92Z_8000     NND12AB92Z
# 45630              CONT_AWD_0066_9700_FA252113D0005_9700           0066
# 47183                           CONT_IDV_NND12AB90Z_8000     NND12AB90Z
# 48419  CONT_AWD_HHSI24103045T_7527_HHSI241201000011I_...  HHSI24103045T
# 48807              CONT_AWD_L601_9700_N0017804D4001_9700           L601
#
#       modification_number  transaction_number parent_award_agency_id  \
# 44342                   1                 NaN                   4732
# 45630                   2                 0.0                   9700
# 47183                   1                 NaN                   4730
# 48419                   0                 0.0                   7527
# 48807                  53                 0.0                   9700
#
#           parent_award_agency_name parent_award_id_piid  \
# 44342  FEDERAL ACQUISITION SERVICE           GS10F0393Y
# 45630                          NaN        FA252113D0005
# 47183  FEDERAL ACQUISITION SERVICE           GS23F0295P
# 48419        INDIAN HEALTH SERVICE    HHSI241201000011I
# 48807                          NaN        N0017804D4001
#
#       parent_award_modification_number  federal_action_obligation  ...  \
# 44342                                0                        0.0  ...
# 45630                                0                        0.0  ...
# 47183                                0                        0.0  ...
# 48419                                0                    40711.0  ...
# 48807                                0                   321899.0  ...
#
#        highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 44342                                NaN                                  NaN
# 45630                                NaN                                  NaN
# 47183                                NaN                                  NaN
# 48419                                NaN                                  NaN
# 48807                                NaN                                  NaN
#
#        highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 44342                                NaN                                  NaN
# 45630                                NaN                                  NaN
# 47183                                NaN                                  NaN
# 48419                                NaN                                  NaN
# 48807                                NaN                                  NaN
#
#        highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 44342                                NaN                                  NaN
# 45630                                NaN                                  NaN
# 47183                                NaN                                  NaN
# 48419                                NaN                                  NaN
# 48807                                NaN                                  NaN
#
#        highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 44342                                NaN                                  NaN
# 45630                                NaN                                  NaN
# 47183                                NaN                                  NaN
# 48419                                NaN                                  NaN
# 48807                                NaN                                  NaN
#
#                                    usaspending_permalink  last_modified_date
# 44342  https://www.usaspending.gov/award/CONT_IDV_NND...          2015-08-24
# 45630  https://www.usaspending.gov/award/CONT_AWD_006...          2015-12-07
# 47183  https://www.usaspending.gov/award/CONT_IDV_NND...          2015-09-30
# 48419  https://www.usaspending.gov/award/CONT_AWD_HHS...          2015-09-14
# 48807  https://www.usaspending.gov/award/CONT_AWD_L60...          2016-10-04
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (845, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2015_NAICS_Eng_5.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive\2015_NAICS_Eng_5.csv'
