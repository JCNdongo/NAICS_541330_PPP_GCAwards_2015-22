# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2016 FULL Award Data Archive'
csv_filename = 'FY2016_All_Contracts_Full_20230608_5.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,27,47,68,70,71,80,113,133,134,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                contract_transaction_unique_key  \
# 0         9700_-NONE-_SPE5E416V2245_0_-NONE-_0
# 1  4900_4900_NSFDACS14T1277_3_NSFDACS12C1299_0
# 2         9700_-NONE-_SPE7MC16M2205_0_-NONE-_0
# 3         9700_-NONE-_SPE7L316M2001_0_-NONE-_0
# 4         9700_-NONE-_SPE8ES16M0226_0_-NONE-_0
#
#                           contract_award_unique_key   award_id_piid  \
# 0         CONT_AWD_SPE5E416V2245_9700_-NONE-_-NONE-   SPE5E416V2245
# 1  CONT_AWD_NSFDACS14T1277_4900_NSFDACS12C1299_4900  NSFDACS14T1277
# 2         CONT_AWD_SPE7MC16M2205_9700_-NONE-_-NONE-   SPE7MC16M2205
# 3         CONT_AWD_SPE7L316M2001_9700_-NONE-_-NONE-   SPE7L316M2001
# 4         CONT_AWD_SPE8ES16M0226_9700_-NONE-_-NONE-   SPE8ES16M0226
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0                   0                 0.0                    NaN
# 1                   3                 0.0                   4900
# 2                   0                 0.0                    NaN
# 3                   0                 0.0                    NaN
# 4                   0                 0.0                    NaN
#
#       parent_award_agency_name parent_award_id_piid  \
# 0                          NaN                  NaN
# 1  NATIONAL SCIENCE FOUNDATION       NSFDACS12C1299
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                              NaN                      78.20  ...
# 1                                0                       0.00  ...
# 2                              NaN                   10794.00  ...
# 3                              NaN                   23576.50  ...
# 4                              NaN                   97039.36  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                        KURT  HESCH                            1336728.0
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                      JOHN  LEONARD                            1036786.0
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                   MATTHEW S LUXTON                            1003459.0
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                    THOMAS B DECKER                             979794.0
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_SPE...          2020-03-26
# 1  https://www.usaspending.gov/award/CONT_AWD_NSF...          2016-10-31
# 2  https://www.usaspending.gov/award/CONT_AWD_SPE...          2020-03-31
# 3  https://www.usaspending.gov/award/CONT_AWD_SPE...          2020-03-28
# 4  https://www.usaspending.gov/award/CONT_AWD_SPE...          2020-04-01
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                     contract_transaction_unique_key  \
# 81                9700_9700_M801_56_N0017810D5975_0
# 230                9700_9700_0022_8_M6785412G0202_0
# 262    1900_-NONE-_SAQMMA15D0089_M001_-NONE-_-NONE-
# 646            9700_-NONE-_N0017316P0524_0_-NONE-_0
# 762  9700_-NONE-_W15QKN14D0034_P00007_-NONE-_-NONE-
#
#                      contract_award_unique_key  award_id_piid  \
# 81       CONT_AWD_M801_9700_N0017810D5975_9700           M801
# 230      CONT_AWD_0022_9700_M6785412G0202_9700           0022
# 262                CONT_IDV_SAQMMA15D0089_1900  SAQMMA15D0089
# 646  CONT_AWD_N0017316P0524_9700_-NONE-_-NONE-  N0017316P0524
# 762                CONT_IDV_W15QKN14D0034_9700  W15QKN14D0034
#
#     modification_number  transaction_number parent_award_agency_id  \
# 81                   56                 0.0                   9700
# 230                   8                 0.0                   9700
# 262                M001                 NaN                    NaN
# 646                   0                 0.0                    NaN
# 762              P00007                 NaN                    NaN
#
#     parent_award_agency_name parent_award_id_piid  \
# 81           DEPT OF DEFENSE        N0017810D5975
# 230          DEPT OF DEFENSE        M6785412G0202
# 262                      NaN                  NaN
# 646                      NaN                  NaN
# 762                      NaN                  NaN
#
#     parent_award_modification_number  federal_action_obligation  ...  \
# 81                                 0                   200000.0  ...
# 230                                0                        0.0  ...
# 262                              NaN                        0.0  ...
# 646                              NaN                   174300.0  ...
# 762                              NaN                        0.0  ...
#
#      highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 81                                 NaN                                  NaN
# 230                                NaN                                  NaN
# 262                      MARK  SCHULER                             250000.0
# 646                                NaN                                  NaN
# 762                                NaN                                  NaN
#
#      highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 81                                 NaN                                  NaN
# 230                                NaN                                  NaN
# 262                    HAROLD  JOHNSON                             200000.0
# 646                                NaN                                  NaN
# 762                                NaN                                  NaN
#
#      highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 81                                 NaN                                  NaN
# 230                                NaN                                  NaN
# 262                      STACEY  TYSON                             180000.0
# 646                                NaN                                  NaN
# 762                                NaN                                  NaN
#
#      highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 81                                 NaN                                  NaN
# 230                                NaN                                  NaN
# 262                 CHRISTOPHER  MORIN                             175000.0
# 646                                NaN                                  NaN
# 762                                NaN                                  NaN
#
#                                  usaspending_permalink  last_modified_date
# 81   https://www.usaspending.gov/award/CONT_AWD_M80...          2016-03-14
# 230  https://www.usaspending.gov/award/CONT_AWD_002...          2015-12-14
# 262  https://www.usaspending.gov/award/CONT_IDV_SAQ...          2021-10-31
# 646  https://www.usaspending.gov/award/CONT_AWD_N00...          2016-01-04
# 762  https://www.usaspending.gov/award/CONT_IDV_W15...          2022-11-10
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (5071, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2016_NAICS_Eng_5.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2016 FULL Award Data Archive\2016_NAICS_Eng_5.csv'
