# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive'
csv_filename = 'FY2015_All_Contracts_Full_20230608_3.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5,27,55,70,71,80,89,113,133,163,168) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                      contract_transaction_unique_key  \
# 0  4732_-NONE-_GS30F0003X_PA0025ADDRESSCHG_-NONE-...
# 1     4735_-NONE-_GS11T08BJD6001_AS887_-NONE-_-NONE-
# 2     4735_-NONE-_GS11T08BJD6001_AS893_-NONE-_-NONE-
# 3             9700_4730_W911RX15F0012_0_GS35F0392P_0
# 4    7001_-NONE-_HSHQE312D00001_P00019_-NONE-_-NONE-
#
#                      contract_award_unique_key   award_id_piid  \
# 0                     CONT_IDV_GS30F0003X_4732      GS30F0003X
# 1                 CONT_IDV_GS11T08BJD6001_4735  GS11T08BJD6001
# 2                 CONT_IDV_GS11T08BJD6001_4735  GS11T08BJD6001
# 3  CONT_AWD_W911RX15F0012_9700_GS35F0392P_4730   W911RX15F0012
# 4                 CONT_IDV_HSHQE312D00001_7001  HSHQE312D00001
#
#   modification_number  transaction_number parent_award_agency_id  \
# 0    PA0025ADDRESSCHG                 NaN                    NaN
# 1               AS887                 NaN                    NaN
# 2               AS893                 NaN                    NaN
# 3                   0                 0.0                   4730
# 4              P00019                 NaN                    NaN
#
#       parent_award_agency_name parent_award_id_piid  \
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3  FEDERAL ACQUISITION SERVICE           GS35F0392P
# 4                          NaN                  NaN
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                              NaN                       0.00  ...
# 1                              NaN                       0.00  ...
# 2                              NaN                       0.00  ...
# 3                                1                   18992.06  ...
# 4                              NaN                       0.00  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_IDV_GS3...          2021-11-02
# 1  https://www.usaspending.gov/award/CONT_IDV_GS1...          2022-04-01
# 2  https://www.usaspending.gov/award/CONT_IDV_GS1...          2022-04-01
# 3  https://www.usaspending.gov/award/CONT_AWD_W91...          2020-04-14
# 4  https://www.usaspending.gov/award/CONT_IDV_HSH...          2015-04-29
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#                      contract_transaction_unique_key  \
# 99                  9700_9700_0001_1_N0017810D6190_0
# 115    3600_-NONE-_VA24712D0025_P00004_-NONE-_-NONE-
# 155                 9700_9700_0004_3_W91CRB14D0024_0
# 1067                9700_9700_0010_1_N6600113D0093_0
# 1293  9700_-NONE-_N0017814D7685_P00003_-NONE-_-NONE-
#
#                   contract_award_unique_key  award_id_piid  \
# 99    CONT_AWD_0001_9700_N0017810D6190_9700           0001
# 115              CONT_IDV_VA24712D0025_3600   VA24712D0025
# 155   CONT_AWD_0004_9700_W91CRB14D0024_9700           0004
# 1067  CONT_AWD_0010_9700_N6600113D0093_9700           0010
# 1293            CONT_IDV_N0017814D7685_9700  N0017814D7685
#
#      modification_number  transaction_number parent_award_agency_id  \
# 99                     1                 0.0                   9700
# 115               P00004                 NaN                    NaN
# 155                    3                 0.0                   9700
# 1067                   1                 0.0                   9700
# 1293              P00003                 NaN                    NaN
#
#      parent_award_agency_name parent_award_id_piid  \
# 99                        NaN        N0017810D6190
# 115                       NaN                  NaN
# 155                       NaN        W91CRB14D0024
# 1067                      NaN        N6600113D0093
# 1293                      NaN                  NaN
#
#      parent_award_modification_number  federal_action_obligation  ...  \
# 99                                  0                    -2501.0  ...
# 115                               NaN                        0.0  ...
# 155                                 0                    30000.0  ...
# 1067                                0                        0.0  ...
# 1293                              NaN                        0.0  ...
#
#       highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 99                                  NaN                                  NaN
# 115                                 NaN                                  NaN
# 155                                 NaN                                  NaN
# 1067                                NaN                                  NaN
# 1293                                NaN                                  NaN
#
#       highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 99                                  NaN                                  NaN
# 115                                 NaN                                  NaN
# 155                                 NaN                                  NaN
# 1067                                NaN                                  NaN
# 1293                                NaN                                  NaN
#
#       highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 99                                  NaN                                  NaN
# 115                                 NaN                                  NaN
# 155                                 NaN                                  NaN
# 1067                                NaN                                  NaN
# 1293                                NaN                                  NaN
#
#       highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 99                                  NaN                                  NaN
# 115                                 NaN                                  NaN
# 155                                 NaN                                  NaN
# 1067                                NaN                                  NaN
# 1293                                NaN                                  NaN
#
#                                   usaspending_permalink  last_modified_date
# 99    https://www.usaspending.gov/award/CONT_AWD_000...          2016-03-15
# 115   https://www.usaspending.gov/award/CONT_IDV_VA2...          2015-05-12
# 155   https://www.usaspending.gov/award/CONT_AWD_000...          2015-04-28
# 1067  https://www.usaspending.gov/award/CONT_AWD_001...          2016-03-16
# 1293  https://www.usaspending.gov/award/CONT_IDV_N00...          2022-12-04
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (8066, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2015_NAICS_Eng_3.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive\2015_NAICS_Eng_3.csv'
