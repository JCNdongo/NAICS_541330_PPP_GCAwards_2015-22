# %%
import csv
import os
import pandas as pd

# %%
# Source CSV file path
source_folder = r'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive'
csv_filename = 'FY2015_All_Contracts_Full_20230608_1.csv'
source_csv_path = os.path.join(source_folder, csv_filename)

# Read the CSV file using pandas
df = pd.read_csv(source_csv_path)
df.head()
# Out:
# C:\Users\mjndo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (27,70,71,80,113,133,163) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          contract_transaction_unique_key  \
# 0  1540_-NONE-_DJB200200_7_-NONE-_-NONE-
# 1       9700_9700_10YY_0_SPM30013DP135_0
# 2    3600_-NONE-_VA24116P0550_0_-NONE-_0
# 3       9700_9700_0001_1_N6264515D5021_0
# 4         2800_2800_2015_0_SS030840114_0
#
#                   contract_award_unique_key award_id_piid modification_number  \
# 0                   CONT_IDV_DJB200200_1540     DJB200200                   7
# 1     CONT_AWD_10YY_9700_SPM30013DP135_9700          10YY                   0
# 2  CONT_AWD_VA24116P0550_3600_-NONE-_-NONE-  VA24116P0550                   0
# 3     CONT_AWD_0001_9700_N6264515D5021_9700          0001                   1
# 4       CONT_AWD_2015_2800_SS030840114_2800          2015                   0
#
#    transaction_number parent_award_agency_id        parent_award_agency_name  \
# 0                 NaN                    NaN                             NaN
# 1                 0.0                   9700                             NaN
# 2                 0.0                    NaN                             NaN
# 3                 0.0                   9700                             NaN
# 4                 0.0                   2800  SOCIAL SECURITY ADMINISTRATION
#
#   parent_award_id_piid parent_award_modification_number  \
# 0                  NaN                              NaN
# 1        SPM30013DP135                                0
# 2                  NaN                              NaN
# 3        N6264515D5021                                0
# 4          SS030840114                                0
#
#    federal_action_obligation  ...  highly_compensated_officer_2_name  \
# 0                   510570.0  ...                                NaN
# 1                      454.3  ...                                NaN
# 2                    16170.0  ...                                NaN
# 3                   129996.0  ...                                NaN
# 4                    37936.3  ...                                NaN
#
#    highly_compensated_officer_2_amount  highly_compensated_officer_3_name  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    highly_compensated_officer_3_amount  highly_compensated_officer_4_name  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    highly_compensated_officer_4_amount  highly_compensated_officer_5_name  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    highly_compensated_officer_5_amount  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                usaspending_permalink  last_modified_date
# 0  https://www.usaspending.gov/award/CONT_IDV_DJB...          2022-09-05
# 1  https://www.usaspending.gov/award/CONT_AWD_10Y...          2015-10-01
# 2  https://www.usaspending.gov/award/CONT_AWD_VA2...          2016-07-19
# 3  https://www.usaspending.gov/award/CONT_AWD_000...          2015-09-30
# 4  https://www.usaspending.gov/award/CONT_AWD_201...          2015-12-20
#
# [5 rows x 294 columns]

# %%
#filtering the data by country, state, congressional district, and business size

# Filter conditions
condition_country = df['recipient_country_code'] == 'USA'
condition_NAICS = df['naics_code'] == 541330
condition_size = df['contracting_officers_determination_of_business_size'] == 'SMALL BUSINESS'

# Combine the conditions using logical AND
combined_condition = condition_country & condition_NAICS & condition_size

# Apply the combined condition to filter the DataFrame
df_filtered = df[combined_condition]
df_filtered.head()
# Out:
#       contract_transaction_unique_key              contract_award_unique_key  \
# 51   9700_9700_0007_1_W9127811D0080_0  CONT_AWD_0007_9700_W9127811D0080_9700
# 220  9700_9700_0025_0_W912DY13D0120_0  CONT_AWD_0025_9700_W912DY13D0120_9700
# 223  9700_9700_0087_0_N4008014D0451_0  CONT_AWD_0087_9700_N4008014D0451_9700
# 238  9700_9700_0003_0_W9128F15D0002_0  CONT_AWD_0003_9700_W9128F15D0002_9700
# 249  9700_9700_0008_0_N4008515D0040_0  CONT_AWD_0008_9700_N4008515D0040_9700
#
#     award_id_piid modification_number  transaction_number  \
# 51           0007                   1                 0.0
# 220          0025                   0                 0.0
# 223          0087                   0                 0.0
# 238          0003                   0                 0.0
# 249          0008                   0                 0.0
#
#     parent_award_agency_id parent_award_agency_name parent_award_id_piid  \
# 51                    9700                      NaN        W9127811D0080
# 220                   9700          DEPT OF DEFENSE        W912DY13D0120
# 223                   9700                      NaN        N4008014D0451
# 238                   9700          DEPT OF DEFENSE        W9128F15D0002
# 249                   9700          DEPT OF DEFENSE        N4008515D0040
#
#     parent_award_modification_number  federal_action_obligation  ...  \
# 51                                 0                    34976.3  ...
# 220                                0                  2422681.0  ...
# 223                                0                   489623.0  ...
# 238                                0                   649010.0  ...
# 249                                0                   244606.0  ...
#
#      highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 51                                 NaN                                  NaN
# 220                   Kabir  Chaudhary                             550000.0
# 223                                NaN                                  NaN
# 238                                NaN                                  NaN
# 249                                NaN                                  NaN
#
#      highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 51                                 NaN                                  NaN
# 220                      Usman  Shakir                             450000.0
# 223                                NaN                                  NaN
# 238                                NaN                                  NaN
# 249                                NaN                                  NaN
#
#      highly_compensated_officer_4_name  highly_compensated_officer_4_amount  \
# 51                                 NaN                                  NaN
# 220                     Stephen  White                             218125.0
# 223                                NaN                                  NaN
# 238                                NaN                                  NaN
# 249                                NaN                                  NaN
#
#      highly_compensated_officer_5_name  highly_compensated_officer_5_amount  \
# 51                                 NaN                                  NaN
# 220                  Lorenza  Peterson                             190394.0
# 223                                NaN                                  NaN
# 238                                NaN                                  NaN
# 249                                NaN                                  NaN
#
#                                  usaspending_permalink  last_modified_date
# 51   https://www.usaspending.gov/award/CONT_AWD_000...          2015-09-30
# 220  https://www.usaspending.gov/award/CONT_AWD_002...          2019-07-07
# 223  https://www.usaspending.gov/award/CONT_AWD_008...          2015-09-30
# 238  https://www.usaspending.gov/award/CONT_AWD_000...          2021-06-04
# 249  https://www.usaspending.gov/award/CONT_AWD_000...          2021-02-10
#
# [5 rows x 294 columns]

# %%
df_filtered.shape
# Out:
# (8736, 294)

# %%
# Define the CSV filename
filtered_csv_filename = '2015_NAICS_Eng_1.csv'

# Define the full path for the filtered CSV file
filtered_csv_path = os.path.join(source_folder, filtered_csv_filename)

# Save the filtered DataFrame as a CSV file
df_filtered.to_csv(filtered_csv_path, index=False)

print(f"Filtered DataFrame saved as '{filtered_csv_path}'")
# Out:
# Filtered DataFrame saved as 'F:\FAU PhD\DISSERTATION\DATABASES\06.30.2023 Data Search\2015 FULL Award Data Archive\2015_NAICS_Eng_1.csv'
